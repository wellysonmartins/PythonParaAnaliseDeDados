# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ## Download: http://github.com/dsacademybr

# %% [markdown]
# ## Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %% [markdown]
# ## Preparando a Conexão com o Twitter

# %%
# Instala o pacote tweepy
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/d5/5f/daac4b4e9b30d7d2a6fdd16a880ff79f27918fe388e4dfc1983dec3a9876/tweepy-3.7.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.11.1 in /home/wellyson/anaconda3/lib/python3.5/site-packages (from tweepy) (2.19.1)
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /home/wellyson/anaconda3/lib/python3.5/site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: PySocks>=1.5.7 in /home/wellyson/anaconda3/lib/python3.5/site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/wellyson/anaconda3/lib/python3.5/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wellyson/anaconda3/lib/python3.5/site-packages (from requests>=2.11.1->tweepy) (2018.8.24)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /home/wellyson/anaconda3/lib/python3.5/site-packages (from requests>=2.11.1->tweepy) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/wellyson/anaconda3/lib/python3.5/site-packages (from requests>=2.11.1->tweepy) (2.7)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
#      |████████████████████████████████| 143kB 1.6MB/s eta 0:00:01
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.0.1 requests-oauthlib-1.2.0 tweepy-3.7.0
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# Veja no manual em pdf como criar sua API no Twitter e configure as suas chaves abaixo.

# %%
# Adicione aqui sua Consumer Key
consumer_key = "xxx"

# %%
# Adicione aqui sua Consumer Secret 
consumer_secret = "xxx"

# %%
# Adicione aqui seu Access Token
access_token = "xxx"

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = "xxx"

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ## Preparando a Conexão com o MongoDB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Big Data', 'Python', 'Data Mining', 'Data Science']

# %% [markdown]
# ## Coletando os Tweets

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'_id': ObjectId('5cd2fae80662f3da0c44bfb6'), 'text': 'RT @GulzebAhmedINC: छोटा काम तो मोदी जी तब नही करते थे जब वो खुद छोटे थे.,\nबचपन से बड़ी बड़ी फेंकने और झांसे देने में माहिर है जनाब.😬\n#Modi…', 'created_at': 'Wed May 08 15:50:59 +0000 2019', 'id_str': '1126152523071442944'}
# {'_id': ObjectId('5cd2faeb0662f3da0c44bfb7'), 'text': 'RT @CoreysDigs: 🗂️ PART TWO has been released 🗂️\n\nMEASLES, MASTERMINDS &amp; MILLIONS\n\nPart II: Big discrepancies and misrepresentations in rep…', 'created_at': 'Wed May 08 15:51:02 +0000 2019', 'id_str': '1126152538766684160'}
# {'_id': ObjectId('5cd2faef0662f3da0c44bfb8'), 'text': 'RT @CultureLabTS_: Aprende #BigData desde cero de forma práctica y efectiva 📊\nhttps://t.co/shwkGfk2e3 https://t.co/06T4yPBUnb', 'created_at': 'Wed May 08 15:51:05 +0000 2019', 'id_str': '1126152552087683076'}
# {'_id': ObjectId('5cd2faf30662f3da0c44bfb9'), 'text': '@chickenlady100 @doritmi @EmmaGPaley @AlexBogdanov18 @Marzo_luna_ @mcfunny @jp_miner @ManticoreHaven @Boxmenot… https://t.co/qu98sMaHlF', 'created_at': 'Wed May 08 15:51:09 +0000 2019', 'id_str': '1126152568516874240'}
# {'_id': ObjectId('5cd2faf30662f3da0c44bfba'), 'text': 'RT @Minyus86: PythonでDeep LearningをやってみるのにGoogle Colabは無料で使えるが、\n前処理、損失関数等を開発する際のデバッグは非効率的で、Google Driveへのアクセスは遅い。\n\nPyCharm Pro(有料、学生は無料)からR…', 'created_at': 'Wed May 08 15:51:10 +0000 2019', 'id_str': '1126152571805003776'}
# {'_id': ObjectId('5cd2faf50662f3da0c44bfbb'), 'text': 'RT @blackgayvideo: #papithugz modelo descatado\n\n🐍🍆Python https://t.co/wVIt9Zd7T8🐍 #PingaGigante #PingaGrande #bigdickalert\n🍑🍑Wet  https://t…', 'created_at': 'Wed May 08 15:51:12 +0000 2019', 'id_str': '1126152577563922433'}
# {'_id': ObjectId('5cd2faf60662f3da0c44bfbc'), 'text': '@CNNPolitics thanks for the additional big data on hypocrisy and institutionalized ignorance 👍👍👍👍👍 and PARROTing \U0001f923\U0001f923… https://t.co/zD19SUAojx', 'created_at': 'Wed May 08 15:51:12 +0000 2019', 'id_str': '1126152580810399744'}
# {'_id': ObjectId('5cd2faf90662f3da0c44bfbd'), 'text': 'RT @ole_b_peters: @trishankkarthik @alex_adamou @bermanjoe @nonergodicMark @Marc_Elsberg @SeloSlav @davidsarac @hulme_oliver @birdxi1988 @E…', 'created_at': 'Wed May 08 15:51:16 +0000 2019', 'id_str': '1126152597323141122'}
# {'_id': ObjectId('5cd2fafa0662f3da0c44bfbe'), 'text': 'Ruby PHP Java Python Go Swift (Java Python Swiftはやってていないが..) に関してはやりたい言語、やりたいことが決まっているならそれに絞って進めればいいと思う。\nProgateだけで… https://t.co/75yv85daAj', 'created_at': 'Wed May 08 15:51:16 +0000 2019', 'id_str': '1126152597566414850'}
# {'_id': ObjectId('5cd2fafa0662f3da0c44bfbf'), 'text': 'DF &gt; A Guide to a Career In Big Data &gt; https://t.co/xT16AHruor #BigData #DataScience #BusinessIntelligence #BI… https://t.co/Crbc3p3cY1', 'created_at': 'Wed May 08 15:51:17 +0000 2019', 'id_str': '1126152598610956288'}
# {'_id': ObjectId('5cd2fafc0662f3da0c44bfc0'), 'text': 'RT @CNBCTV18News: A @livemint report says the NSSO has found that 36% of companies in the MCA data base are untraceable or wrongly classifi…', 'created_at': 'Wed May 08 15:51:19 +0000 2019', 'id_str': '1126152607104245765'}
# {'_id': ObjectId('5cd2fafe0662f3da0c44bfc1'), 'text': 'RT @InformaticsNHS: Presenting this morning to @SalfordUni Data Science masters students on the work of our @NCA_Datascience team to encour…', 'created_at': 'Wed May 08 15:51:21 +0000 2019', 'id_str': '1126152618391298049'}
# {'_id': ObjectId('5cd2faff0662f3da0c44bfc2'), 'text': '打印出来，贴到桌前。', 'created_at': 'Wed May 08 15:51:21 +0000 2019', 'id_str': '1126152619104378880'}
# {'_id': ObjectId('5cd2fb020662f3da0c44bfc3'), 'text': 'Latif, A., Limani, F. and Tochtermann, K., 2019. A Generic Research Data Infrastructure for Long Tail Research Data… https://t.co/pRgs9MCTj9', 'created_at': 'Wed May 08 15:51:25 +0000 2019', 'id_str': '1126152632953921539'}
# {'_id': ObjectId('5cd2fb030662f3da0c44bfc4'), 'text': 'RT @blackgayvideo: #papithugz modelo descatado\n\n🐍🍆Python https://t.co/wVIt9Zd7T8🐍 #PingaGigante #PingaGrande #bigdickalert\n🍑🍑Wet  https://t…', 'created_at': 'Wed May 08 15:51:25 +0000 2019', 'id_str': '1126152636024201216'}
# {'_id': ObjectId('5cd2fb040662f3da0c44bfc5'), 'text': 'RT @KIMAGA4EVER: Its 34 yr old information, and if there was anything illegal in it they woulda nailed him for it. Big fat #NothingBurger.…', 'created_at': 'Wed May 08 15:51:27 +0000 2019', 'id_str': '1126152640444940289'}
# {'_id': ObjectId('5cd2fb070662f3da0c44bfc6'), 'text': 'Time to bring sharp Bob back miss @_ritusingh!!  Current hair out of shape!!  #hair #haircut #bob #shorthair', 'created_at': 'Wed May 08 15:51:30 +0000 2019', 'id_str': '1126152653505875970'}
# {'_id': ObjectId('5cd2fb080662f3da0c44bfc7'), 'text': 'RT @muglikar_: Statements by INC not backed by any data\n1. Farmers in trouble\n2. There are no jobs\n3. FDI is low.\n4. Economy is down\n5. GST…', 'created_at': 'Wed May 08 15:51:30 +0000 2019', 'id_str': '1126152656253116417'}
# {'_id': ObjectId('5cd2fb0a0662f3da0c44bfc8'), 'text': '@JohnCleese @MotCityComicCon So excited to meet you!! My parents never understood why their little 8 year old girl… https://t.co/hTIz3dKXar', 'created_at': 'Wed May 08 15:51:33 +0000 2019', 'id_str': '1126152666877444104'}
# {'_id': ObjectId('5cd2fb0c0662f3da0c44bfc9'), 'text': 'RT @pamela_herd: While Trump should release his tax returns, I am not thrilled that the NYT used de-identified publicly released data to do…', 'created_at': 'Wed May 08 15:51:35 +0000 2019', 'id_str': '1126152675316391936'}
# {'_id': ObjectId('5cd2fb0f0662f3da0c44bfca'), 'text': 'RT @MomentsWithBren: Our world is really evolving.\n\n Start learning and gaining more top tech skills. \n\nBig Data Analysis\nCoding and Progra…', 'created_at': 'Wed May 08 15:51:38 +0000 2019', 'id_str': '1126152689727963137'}
# {'_id': ObjectId('5cd2fb130662f3da0c44bfcb'), 'text': "RT @fhsalzburg: 📢 Ab sofort könnt ihr euch für die Sommerkurse der @ditact women's IT studies anmelden! &gt;40 Kurse zu Themen wie Cybercrime…", 'created_at': 'Wed May 08 15:51:42 +0000 2019', 'id_str': '1126152703355305984'}
# {'_id': ObjectId('5cd2fb140662f3da0c44bfcc'), 'text': 'RT @k5dru: Celebrate the little victories: just pickled a dataframe in #python', 'created_at': 'Wed May 08 15:51:42 +0000 2019', 'id_str': '1126152706723332097'}
# {'_id': ObjectId('5cd2fb140662f3da0c44bfcd'), 'text': '@DG_Rand 🙋🏻\u200d♀️\nMeasuring the effects of information from data science on cognition related to design of complex sys… https://t.co/cuA4JqaTcA', 'created_at': 'Wed May 08 15:51:43 +0000 2019', 'id_str': '1126152708707299330'}
# {'_id': ObjectId('5cd2fb140662f3da0c44bfce'), 'text': 'RT @InsightFellows: Deploy your Flask app in the cloud in minutes, regardless of prior experience. #AWS #Docker #DevOps #python  https://t.…', 'created_at': 'Wed May 08 15:51:43 +0000 2019', 'id_str': '1126152710598856704'}
# {'_id': ObjectId('5cd2fb150662f3da0c44bfcf'), 'text': 'RT @TamiS_3264: Learning bcrypt today...I kinda like it ✌️\n#coding #python #CodeNewbie', 'created_at': 'Wed May 08 15:51:44 +0000 2019', 'id_str': '1126152714877054976'}
# {'_id': ObjectId('5cd2fb170662f3da0c44bfd0'), 'text': 'RT @ProgrammerBooks: Python Graphics : https://t.co/30HDoNIrtX\n#python #javascript #angular #reactjs #vuejs #perl #ruby #Csharp #Java #linu…', 'created_at': 'Wed May 08 15:51:46 +0000 2019', 'id_str': '1126152721172762625'}
# {'_id': ObjectId('5cd2fb180662f3da0c44bfd1'), 'text': 'RT @hsianghui: How to read most commonly used file formats in Data Science (using #python)? https://t.co/urIseGj5o8', 'created_at': 'Wed May 08 15:51:47 +0000 2019', 'id_str': '1126152725593567233'}
# {'_id': ObjectId('5cd2fb1c0662f3da0c44bfd2'), 'text': "RT @PlumRemson: If we don't accurately collect data on vaccine injury, how can anyone do a risk/benefit calculation… https://t.co/FkRbOfzkpN", 'created_at': 'Wed May 08 15:51:50 +0000 2019', 'id_str': '1126152740667822080'}
# {'_id': ObjectId('5cd2fb1c0662f3da0c44bfd3'), 'text': 'RT @conlon_chris: We will call today the official launch of pyBLP, our python package for differentiated products demand estimation.  First…', 'created_at': 'Wed May 08 15:51:51 +0000 2019', 'id_str': '1126152741208850434'}
# {'_id': ObjectId('5cd2fb1d0662f3da0c44bfd4'), 'text': 'RT @krutledgeb: Reflecting on the year &amp; thinking forward to next year with school &amp; district administrators! Is data-driven decision makin…', 'created_at': 'Wed May 08 15:51:52 +0000 2019', 'id_str': '1126152747991089158'}
# {'_id': ObjectId('5cd2fb220662f3da0c44bfd5'), 'text': 'RT @KSUprofessional: CPE is excited to partner with the @KSUDataScience Institute to offer three cutting-edge certificates that are open to…', 'created_at': 'Wed May 08 15:51:56 +0000 2019', 'id_str': '1126152765582073856'}
# {'_id': ObjectId('5cd2fb250662f3da0c44bfd6'), 'text': '人工知能を作りたいというと聞こえはいいけど、AIで架空の女性を描かせたものに組み合わせてみるとあら不思議。お下劣なクリエイティビティ\n\n※画像の女性は実在していません。\n\n#機械学習 #深層学習 #ディープラーニング… https://t.co/IczIXAt8VR', 'created_at': 'Wed May 08 15:51:59 +0000 2019', 'id_str': '1126152776898101248'}
# {'_id': ObjectId('5cd2fb250662f3da0c44bfd7'), 'text': 'RT @schoollah: Jurusan seperti:\n\n1. Finance/Business/Management\n2. Engineering\n3. Corporate Communication\n4. IT/Computer Science\n5. Mathema…', 'created_at': 'Wed May 08 15:51:59 +0000 2019', 'id_str': '1126152778403835904'}
# {'_id': ObjectId('5cd2fb270662f3da0c44bfd8'), 'text': '@ELINTNews He is no joke; he worked in Rafael and participated in the develpoment of the Python-3 and Python-4 air… https://t.co/5GUrVCOBlK', 'created_at': 'Wed May 08 15:52:02 +0000 2019', 'id_str': '1126152787153309696'}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6a9070444200> in <module>()
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~/anaconda3/lib/python3.5/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     411             else:
#     412                 cache_content = False
# --> 413                 data = self._fp.read(amt)
#     414                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     415                     # Close the connection when no data is returned
#
# ~/anaconda3/lib/python3.5/http/client.py in read(self, amt)
#     446             # Amount is given, implement using readinto
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#     450         else:
#
# ~/anaconda3/lib/python3.5/http/client.py in readinto(self, b)
#     476
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#     480         if self.length is not None:
#
# ~/anaconda3/lib/python3.5/http/client.py in _readinto_chunked(self, b)
#     571         try:
#     572             while True:
# --> 573                 chunk_left = self._get_chunk_left()
#     574                 if chunk_left is None:
#     575                     return total_bytes
#
# ~/anaconda3/lib/python3.5/http/client.py in _get_chunk_left(self)
#     539                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     540             try:
# --> 541                 chunk_left = self._read_next_chunk_size()
#     542             except ValueError:
#     543                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.5/http/client.py in _read_next_chunk_size(self)
#     499     def _read_next_chunk_size(self):
#     500         # Read the next chunk size from the file
# --> 501         line = self.fp.readline(_MAXLINE + 1)
#     502         if len(line) > _MAXLINE:
#     503             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295                 raise
#     296         except OpenSSL.SSL.WantReadError:
# --> 297             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     298                 raise timeout('The read operation timed out')
#     299             else:
#
# ~/anaconda3/lib/python3.5/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/anaconda3/lib/python3.5/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/anaconda3/lib/python3.5/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/lib/python3.5/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# ## --> Pressione o botão Stop na barra de ferramentas para encerrar a captura dos Tweets

# %% [markdown]
# ## Consultando os Dados no MongoDB

# %%
mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5cd2fae80662f3da0c44bfb6'),
#  'created_at': 'Wed May 08 15:50:59 +0000 2019',
#  'id_str': '1126152523071442944',
#  'text': 'RT @GulzebAhmedINC: छोटा काम तो मोदी जी तब नही करते थे जब वो खुद छोटे थे.,\nबचपन से बड़ी बड़ी फेंकने और झांसे देने में माहिर है जनाब.😬\n#Modi…'}

# %% [markdown]
# ## Análise de Dados com Pandas e Scikit-Learn

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                         created_at  \
# 0   Wed May 08 15:50:59 +0000 2019
# 1   Wed May 08 15:51:02 +0000 2019
# 2   Wed May 08 15:51:05 +0000 2019
# 3   Wed May 08 15:51:09 +0000 2019
# 4   Wed May 08 15:51:10 +0000 2019
# 5   Wed May 08 15:51:12 +0000 2019
# 6   Wed May 08 15:51:12 +0000 2019
# 7   Wed May 08 15:51:16 +0000 2019
# 8   Wed May 08 15:51:16 +0000 2019
# 9   Wed May 08 15:51:17 +0000 2019
# 10  Wed May 08 15:51:19 +0000 2019
# 11  Wed May 08 15:51:21 +0000 2019
# 12  Wed May 08 15:51:21 +0000 2019
# 13  Wed May 08 15:51:25 +0000 2019
# 14  Wed May 08 15:51:25 +0000 2019
# 15  Wed May 08 15:51:27 +0000 2019
# 16  Wed May 08 15:51:30 +0000 2019
# 17  Wed May 08 15:51:30 +0000 2019
# 18  Wed May 08 15:51:33 +0000 2019
# 19  Wed May 08 15:51:35 +0000 2019
# 20  Wed May 08 15:51:38 +0000 2019
# 21  Wed May 08 15:51:42 +0000 2019
# 22  Wed May 08 15:51:42 +0000 2019
# 23  Wed May 08 15:51:43 +0000 2019
# 24  Wed May 08 15:51:43 +0000 2019
# 25  Wed May 08 15:51:44 +0000 2019
# 26  Wed May 08 15:51:46 +0000 2019
# 27  Wed May 08 15:51:47 +0000 2019
# 28  Wed May 08 15:51:50 +0000 2019
# 29  Wed May 08 15:51:51 +0000 2019
# 30  Wed May 08 15:51:52 +0000 2019
# 31  Wed May 08 15:51:56 +0000 2019
# 32  Wed May 08 15:51:59 +0000 2019
# 33  Wed May 08 15:51:59 +0000 2019
# 34  Wed May 08 15:52:02 +0000 2019
#
#                                                  text
# 0   RT @GulzebAhmedINC: छोटा काम तो मोदी जी तब नही...
# 1   RT @CoreysDigs: 🗂️ PART TWO has been released ...
# 2   RT @CultureLabTS_: Aprende #BigData desde cero...
# 3   @chickenlady100 @doritmi @EmmaGPaley @AlexBogd...
# 4   RT @Minyus86: PythonでDeep LearningをやってみるのにGoog...
# 5   RT @blackgayvideo: #papithugz modelo descatado...
# 6   @CNNPolitics thanks for the additional big dat...
# 7   RT @ole_b_peters: @trishankkarthik @alex_adamo...
# 8   Ruby PHP Java Python Go Swift (Java Python Swi...
# 9   DF &gt; A Guide to a Career In Big Data &gt; h...
# 10  RT @CNBCTV18News: A @livemint report says the ...
# 11  RT @InformaticsNHS: Presenting this morning to...
# 12                                         打印出来，贴到桌前。
# 13  Latif, A., Limani, F. and Tochtermann, K., 201...
# 14  RT @blackgayvideo: #papithugz modelo descatado...
# 15  RT @KIMAGA4EVER: Its 34 yr old information, an...
# 16  Time to bring sharp Bob back miss @_ritusingh!...
# 17  RT @muglikar_: Statements by INC not backed by...
# 18  @JohnCleese @MotCityComicCon So excited to mee...
# 19  RT @pamela_herd: While Trump should release hi...
# 20  RT @MomentsWithBren: Our world is really evolv...
# 21  RT @fhsalzburg: 📢 Ab sofort könnt ihr euch für...
# 22  RT @k5dru: Celebrate the little victories: jus...
# 23  @DG_Rand 🙋🏻‍♀️\nMeasuring the effects of infor...
# 24  RT @InsightFellows: Deploy your Flask app in t...
# 25  RT @TamiS_3264: Learning bcrypt today...I kind...
# 26  RT @ProgrammerBooks: Python Graphics : https:/...
# 27  RT @hsianghui: How to read most commonly used ...
# 28  RT @PlumRemson: If we don't accurately collect...
# 29  RT @conlon_chris: We will call today the offic...
# 30  RT @krutledgeb: Reflecting on the year &amp; t...
# 31  RT @KSUprofessional: CPE is excited to partner...
# 32  人工知能を作りたいというと聞こえはいいけど、AIで架空の女性を描かせたものに組み合わせてみる...
# 33  RT @schoollah: Jurusan seperti:\n\n1. Finance/...
# 34  @ELINTNews He is no joke; he worked in Rafael ...

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#             word  count
# 0             rt     24
# 1          https     20
# 2             co     17
# 3            the     13
# 4           data     13
# 5         python     13
# 6             to     12
# 7             in     11
# 8            and      9
# 9             of      8
# 10            is      6
# 11            it      5
# 12           big      5
# 13            on      5
# 14       science      4
# 15           for      4
# 16          year      3
# 17            gt      3
# 18           our      3
# 19           are      3
# 20          java      3
# 21           amp      3
# 22          that      3
# 23          hair      2
# 24            he      2
# 25          with      2
# 26           how      2
# 27            by      2
# 28         there      2
# 29   pingagrande      2
# 30  pingagigante      2
# 31            de      2
# 32           wet      2
# 33            we      2
# 34           old      2
# 35         today      2
# 36            if      2
# 37   information      2
# 38           has      2
# 39          used      2
# 40          part      2
# 41     descatado      2
# 42        coding      2
# 43     papithugz      2
# 44      research      2
# 45            बड      2
# 46          ruby      2
# 47            no      2
# 48        modelo      2
# 49           bob      2

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
